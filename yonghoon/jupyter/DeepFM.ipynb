# %%
import torch
import torchrec
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/ml/recsys/jupyter/deepfm.ipynb Cell 1' in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B115.85.183.238/opt/ml/recsys/jupyter/deepfm.ipynb#ch0000000vscode-remote?line=0'>1</a> import torch
# ----> <a href='vscode-notebook-cell://ssh-remote%2B115.85.183.238/opt/ml/recsys/jupyter/deepfm.ipynb#ch0000000vscode-remote?line=1'>2</a> import torchrec
#
# File /opt/conda/envs/torch/lib/python3.8/site-packages/torchrec/__init__.py:8, in <module>
#       <a href='file:///opt/conda/envs/torch/lib/python3.8/site-packages/torchrec/__init__.py?line=0'>1</a> #!/usr/bin/env python3
#       <a href='file:///opt/conda/envs/torch/lib/python3.8/site-packages/torchrec/__init__.py?line=1'>2</a> # Copyright (c) Meta Platforms, Inc. and affiliates.
# ...

# %%
torch.cuda.is_available()
# Out:
# True
